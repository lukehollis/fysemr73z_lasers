# %% [markdown]
# # DDS DINO-X: Detection on a local image
#
# This notebook uses the `dds-cloudapi-sdk` to call the DINO-X detection API on a local image at `./data/copan_dem_01m_raster.jpg`.
#
# It is organized into cells for imports, configuration, task creation, execution, result viewing, and visualization.
#
# Notes:
# - Set `DDS_API_TOKEN` via a `.env` file or environment. The notebook loads `.env` and reads `os.environ["DDS_API_TOKEN"]`.
# - Get DDS_API_TOKEN for free here: https://cloud.deepdataspace.com/apply-token

# %% [markdown]
# ## Imports

# %%
import os
import json
from dotenv import load_dotenv
from dds_cloudapi_sdk import Config, Client
from dds_cloudapi_sdk.tasks.v2_task import V2Task, create_task_with_local_image_auto_resize
from dds_cloudapi_sdk.visualization_util import visualize_result
from IPython.display import Image

# %% [markdown]
# ## Configure client (API token)

# %%
load_dotenv()
TOKEN = os.environ["DDS_API_TOKEN"]
config = Config(TOKEN)
client = Client(config)

# %% [markdown]
# ## Set image path and DINO-X parameters

# %%
image_path = "./data/copan_dem_01m_raster.jpg"
api_path = "/v2/task/dinox/detection"

prompt = {"type": "universal", "universal": 1}

api_body = {
    "model": "DINO-X-1.0",
    "prompt": prompt,
    "targets": ["bbox", "mask"],
    "bbox_threshold": 0.25,
    "iou_threshold": 0.8,
    "mask_format": "coco_rle",
}

# %% [markdown]
# ## Create task with local image (auto-resized by SDK)

# %%
task = create_task_with_local_image_auto_resize(
    api_path=api_path,
    api_body_without_image=api_body,
    image_path=image_path,
)

# %% [markdown]
# ## Run task and wait for result

# %%
task.set_request_timeout(10)  # optional timeout in seconds
client.run_task(task)
print("Task completed.")
# Out:
# Task completed.

# %% [markdown]
# ## Inspect raw result JSON

# %%
print(json.dumps(task.result, indent=2, ensure_ascii=False))

os.makedirs("outputs", exist_ok=True)
with open("outputs/dinox_result.json", "w", encoding="utf-8") as f:
    json.dump(task.result, f, indent=2, ensure_ascii=False)
print("Saved: outputs/dinox_result.json")
# Out:
# {
#   "objects": [
#     {
#       "bbox": [
#         7,
#         3,
#         2004,
#         1953
#       ],
#       "category": "map",
#       "mask": {
#         "counts": "Pd?c0Ul1b0gUNnNW5NhJ;XY1NPiNMeLX1:Mi0QOhNe0`1IcNB@=hZ1@UiNMeLX1:Mi0QOhNe0`1IcNB@=WZ15]iNEbLT184g0P1If0c8bLef0m0XSOL]Lf3Q1b3S1nGb1n0aLIc0J`13Sh0[OXXOn0P1_4[Mh2LmG54W2[2QMmNW10]h0bNhXOn0P1_4[Mh2LmG54W2[2QMmNW10\\h0dNjXOh0R1c4WMi2HTH5MU2S5YMlL=Mhe0UN^\\O;l0k4SMk2FUH9JQ2b;dMWDb0j0o1WO[12c6<WHIb0W5QMm2FUH7IQ2l>POlAn1EQ7H`HIb0W5QMm2FUH7IQ2l>POlAn1EP7LTH^O\\M:_3X5QMm2FTH8J:H>\\b0fNl^O1fN0Y2S:\\NZHWOdM309]3[5SMk2CXH:I5K?ng0d0kWOR5h0lITOe09hN3d2K`Mb51R44iF6N<\\j0EmTOW1T1j0MRNTOe09hN3d2K`Mb51R44iF6N<\\j0EmTOW1T1j02kMWOf02mN8]2HeMl?4d@3O>Zj0_ObUOk0R1n0^OWN^Od0HVO:Z2FgMm?2nAd0[j0KaUOW1:WNbM=>A<k0VO?>hNn?1mAf0Zm0o0_SOXN^M0d0>QOj0;hN]b0i0X==mROjN^M0d0>QOj0;hN]b0i0X==UUOmNoJQ1[c0Dc<<gUOTOVJ4gc09]<>gUOQO]J0ec0<Y<c0eUOQO]J0ec0<Y<c0fJWO`5g0bJUO`5k0`JWO^5i0bJWO^5j0aJWO_5h0bJXO]5h0fJUOZ5k0fJUOZ5k0`k000000000000SlNQOd;o0[DVOa;j0_DVOa;j0^DXOa;h0`DWO`;i0`DWO`;i0`DWO`;h0bDXO];h0cDZOjWOJ[S1m0iDBPXO@lR1n0TEBPXO@lR1n0TEMj:3UE2g:NYE4e:L[E4e:L\\E4b:LbE1^:OcE1\\:OjEGZ:9fEGZ:9Yi0001O0000O1N20000000000000001O0O100O1000000000000O2O3M00000000000001O000000000M30001N10000000000O10000000001O000N110000000000000000000000O1000O1000000000000000000dXNQObb1o0U]N\\Oib1d0W]N\\Oib1d0W]N\\Oib1d0P]NDob1<m\\NIRc17n\\NIRc17m\\NLQc14o\\NJSc17l\\NHUc18j\\NHWc18i\\NHWc18i\\NFYc1:g\\NEZc1<c\\NE^c1;b\\NE^c1;b\\NE^c1;b\\NE^c1;b\\ND_c1<a\\ND_c1>_\\N@cc1`0]\\N_Odc1b0[\\N^Oec1b0[\\N^Oec1c0Z\\N]OkL]OUf1V1o\\N^OlL\\OO1`e1W1c]N\\OnL]ON0ae1W1c]N\\OnL]ON0ae1W1d]N[OmL^ON0ae1X1c]NYOoL^OTf1Z1n\\NVOic1l0V\\NQOlc1o0T\\NQOlc1o0T\\NQOlc1o0T\\NQOlc1m0V\\NUOhc1k0X\\NUOhc1k0Y\\NTOgc1l0X\\NVOgc1j0Y\\NYOdc1g0\\\\NYOdc1f0]\\N_O^L@_f1Q1R]N5jb1KT]N8kb1HU]N8kb1GU]N:kb1FU]N;jb1CZ\\NjNQNf12ZNbd1V1X^N`0VMZNbd1V1X^N`0VMZNbd1V1Y^N`0fb1_OZ]Na0fb1_O[]N`0eb1@[]N`0eb1_O\\]Na0db1@Z]Na0TMZNdd1U1W^NE]LMe0]Ofd1Q1X^NE]LMe0]Ofd1Q1V^NFbLJa0Bed1n0X^NFbLK`0Bed1l0Y^NI^LNb0]Ogd1l0Y^NI^LNb0]Ogd1l0X^NK]L3=WOnd1k0X^NU1eLPNJIRe1R1]^NY1eLkMMKPe1Q1^^NY1eLkMMKPe1Q1^^NY1gLgMNMnd1S1]^NL`L:ke1Kc]NLbL<he1Hj]NG_La0ge1Hj]NG_La0ge1HQ^N_OZLh0ee1IS^NZO\\Ll0ae1JW^NSO]Lo0^e1NU^NSO]Lo0^e10W^NmN[LS1^e10i^N4Ua1Lj^N5Va1Kj^N5Va1Ki^N6Wa1Jg^N6[a1J_^N8ea1H[^N8ea1HW^N;ja1ES^N;Pb1EP^N:Qb1FQ^N7Pb1IP^N7Pb1IQ^N5Pb1KQ^N1Rb1On]N0Sb10m]N0Sb10o]NLSb14o]NIQb18R^NSOdKO]f1n0o]NSOdKO]f1n0P^NoNhK1Xf1Q1o]NCna1=S^NBma1>S^NBma1>S^NCla1=T^NEja1;V^NEja1;V^NEja1;V^NEja1;a]NiNfLl0ie1;`]NkNfLj0je1;`]NoNbLg0me1:a]NoNbLg0me1:a]NSO^Lc0Qf1:`]NXOYLa0c0QOid1V1[^N>lL^Ngd1T1]^N>lL^Ngd1S1^^NXO[L`0b0QOfd1X1]^NWO]L=Qf1<b]NWO_L;oe1>b]NWO_L;oe1>b]NWOaL8ne1a0b]NVOYL`0Uf1:b]N9`b1G`]N9`b1Ga]NOXLiNYf1X1b]NHRMRObd1S1^^NCoLDbd1i0`^N@oLHad1h0`^N@oLHad1h0b^N\\OmLNad1f0`^N]OPMM`d1f0_^N]ORML`d1g0^^N]ORML`d1g0]^N^OSMK`d1f0^^N\\OUMN]d1f0_^NZOWMNZd1h0_^NZOWMNZd1h0k^NmNlL:Zd1i0Y`NVOg_1i0Z`NWOg_1h0Y`NXOg_1h0Y`NXOg_1h0Z`NVOg_1k0X`NUOh_1k0X`NSOj_1m0V`NSOj_1m0X`NQOh_1o0X`NQOh_1o0c]NQOSO0Zc1o0c]NQOSO0Zc1P1_]NWOSOI^c1P1^]N[OQOEac1P1^]N_OnN@dc1Q1^]N_OnN@dc1Q1\\]NBoN\\Ofc1R1[]NCnN[Ogc1R1]]NBlN[Ogc1S1]]NBlN[Ogc1U1_]N[Ohd1e0Y[NZOgd1f0Z[NXOgd1h0Y[NXOgd1h0Z[NWOfd1i0Z[NWOfd1i0\\[NUOgMN]e1n0k\\NTOfM3\\e1i0n\\NTOfM3\\e1i0S]NoNaM8\\e1i0T]NmNdM7Xe1l0W]NjNcM8Ve1n0W]NjNcM8Ve1o0d^NoN\\a1S1c^NlN]a1U1c^NjN\\a1W1d^NiN\\a1X1e^NfN[a1\\1d^NcN\\a1]1e^NbN[a1^1e^NbN[a1^1V5NkYNdNe`1Z1[_NjNc`1S1^_NQO``1o0`_NQO``1o0^_NYO\\`1g0c_N[O\\`1e0a_N_O^`1a0b_N_O^`1a0b_NA\\`1?d_NA\\`1?f_N_OZ`1a0f_N_OZ`1a0f_N@X`1`0j_N_OW`1`0j_N^OW`1b0i_N^OW`1b0i_N\\OY`1b0Z^NmN[M?[d1d0[^NlNZM`0[d1d0k_N\\OU`1d0k_N\\OU`1d0k_NDm_1<T`NWO_JK]e1n0S`NZO^JH_e1n0S`NZO^JH_e1n0S`NDm_1<S`NDm_1<S`NDm_1<S`NDm_1<^_NmNaKh0Re1;[_NQOaKa0We1>W_NUO_K<[e1?V_NUO_K<[e1a0d^NmNmK;36]e1b0a^NQOlK952`e1d0_^NQOmK86BH9fe1l0_^NQOmK86BH9fe1l0]^NROTL:0H_e1l0]^NROUL:NH`e1l0]^NnN\\L:IK^e1m0U_NPOgKOWe1P1R_NQOgKOWe1P1S_NoNhKLYe1U1o^NoNja1Q1V^NoNja1Q1V^NoNja1o0W^NSOha1m0X^NTOYNIQM2db1Q1RbNTOXN8f_1d0RbNTOXN8f_1d0RbNSOWN;g_1b0UbNmNYN?b_1d0ceN\\O]Z1d0ceN\\O]Z1d0ceN\\O]Z1d0UdNPOVJ<ea1d0UdNPOWJ;da1d0VdNPOXJ;ba1e0VdNPOXJ;ba1e0RdNQObJ7\\a1g0RdNQOeJ7Ya1h0RdNoNnJ2Pa1o0RdNoNnJ2Pa1o0]cNmNZJ2Y12Pa1m0TcN\\OaJD\\13o`1m0nbNBgJ^Oe01]O2Yb1m0nbNBgJ^Oe01]O2Yb1m0kbNEhL@]`1k0jbNE`L^OjM6lb1g0hbN_O_J ...
#         "size": [
#           1957,
#           2012
#         ],
#         "format": "coco_rle"
#       },
#       "score": 0.4491509795188904
#     },
#     {
#       "bbox": [
#         1518,
#         520,
#         1607,
#         603
#       ],
#       "category": "flower",
#       "mask": {
#         "counts": "kXmj2`0dl15L0N7J6K5K0O5J6K4M001N2O2L4N000O3N1O0O2N102N0N200O10000O1000000000000000000N20000000000000000000000O11O0000000000002L2000001O00001N102N001N101O1O003K3O2M102M4J7K104J6J?\\O70UdQh0",
#         "size": [
#           1957,
#           2012
#         ],
#         "format": "coco_rle"
#       },
#       "score": 0.3729618787765503
#     },
#     {
#       "bbox": [
#         4,
#         729,
#         87,
#         914
#       ],
#       "category": "window",
#       "mask": {
#         "counts": "m\\8V1?lN\\j1V3RO0EP1WO=E9H6K004K3OO00000002N00000000001O000001O0000O1000000000000000000O100000000000O100000000000N2000N2000O100000000O10O1000000O10000N2000000O2O001\\LgXNY1\\g1kM[XN_Oe0`2Rg1lMiYNc0gNBbg1KgYNc0gNBfg1D[ZN2]NNYeUc3",
#         "size": [
#           1957,
#           2012
#         ],
#         "format": "coco_rle"
#       },
#       "score": 0.3593641221523285
#     },
#     {
#       "bbox": [
#         1038,
#         750,
#         1119,
#         867
#       ],
#       "category": "latch",
#       "mask": {
#         "counts": "\\ZTn1;gl17L0M6L4L2O00001M20002N000000000O1000000000000000000001O00000000000000000000YUNSOVi1m0YVN?lh1ATWN?lh1ARWNc0lh1]OSWNd0mh1]OPWNe0Pi1[OPWNe0Pi1[OnVNg0Ri1ZOlVNg0Ti1ZOjVNg0Vi1YOjVNg0Vi1\\OcVNh0]i1`1000000000000000000000000000O10002N0O10001M201N103M1L9H20S1jN\\nWe1",
#         "size": [
#           1957,
#           2012
#         ],
#         "format": "coco_rle"
#       },
#       "score": 0.3302551507949829
#     },
#     {
#       "bbox": [
#         183,
#         762,
#         240,
#         835
#       ],
#       "category": "flower",
#       "mask": {
#         "counts": "V`n:;jl10J?D7K3N0M7J5K3O002M3M3L20001O1O00001O0O3N00001O00001O002N0000001O0001O000000000000002M100N201N101N3L200O2N3M104AgkgY3",
#         "size": [
#           1957,
#           2012
#         ],
#         "format": "coco_rle"
#       },
#       "score": 0.3268083333969116
#     },
#     {
#       "bbox": [
#         1004,
#         812,
#         1065,
#         869
#       ],
#       "category": "latch",
#       "mask": {
#         "counts": "W`Ql1;hl14J6N0L5L4M5M0M7L1N4M1O001O0N4N0000000000000O10000000000000000000000000000000N1100000000000000000000001O0000001N3N008H5J;A50VY[h1",
#         "size": [
#           1957,
#           2012
#         ],
#         "format": "coco_rle"
#       },
#       "score": 0.28776782751083374
#     }
#   ]
# }
# Saved: outputs/dinox_result.json

# %% [markdown]
# ## Visualize results

# %%
out_dir = "outputs/dinox"
os.makedirs(out_dir, exist_ok=True)
visualize_result(image_path=image_path, result=task.result, output_dir=out_dir)
print(f"Saved visualizations to: {out_dir}")
display(Image("outputs/dinox/annotated_image.jpg"))
# Out:
# Saved visualizations to: outputs/dinox

# %% [markdown]
# ### Notes
# - For the DINO-X region captioning API (`/v2/task/dinox/region_vl`), use detected bounding boxes as regions and request targets like `caption`.
# - If you consistently call on the same image, you can consider using `session_id` to avoid resending the image payload.
# - DEM/remote-sensing/monochrome content may not yield meaningful detections with general vision models; tweaking prompts or thresholds can sometimes help.
